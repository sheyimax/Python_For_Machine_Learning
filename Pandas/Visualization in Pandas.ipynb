# %%
import numpy as np
import pandas as pd
import os

# %%
os.chdir('C:\\Users\\Sheyi_max\\Desktop\\ML\\ML_Datasheet_Excel _Sample\\Salary_Dataset')
os.getcwd()
# Out:
# 'C:\\Users\\Sheyi_max\\Desktop\\ML\\ML_Datasheet_Excel _Sample\\Salary_Dataset'

# %%
software = pd.read_csv('Software_Professional_Salaries.csv')
software.shape
software.columns
# Out:
# Index(['Rating', 'Company Name', 'Job Title', 'Salary', 'Salaries Reported',
#        'Location'],
#       dtype='object')

# %%
#Lets work with the salary ratings using the box plot

software['Rating'].plot.box()
# Out:
# <Axes: >

# %%
#Making the box plot vertical

software['Rating'].plot.box(vert=False)
# Out:
# <Axes: >

# %%
#Using the plot() function

software['Salary'].plot()
# Out:
# <Axes: >

# %%
#To get the bar chart

software['Rating'].plot.bar()
# Out:
# <Axes: >

# %%
software['Rating'].plot.barh()
# Out:
# <Axes: >

# %%
#I reduce the rows to first 200 from 22000+ which for faster loading time

a = pd.read_csv('Software_Professional_Salaries.csv', nrows=200)
a.shape
# Out:
# (200, 6)

# %%
#How to get the histogram graph

a['Rating'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Using the bin for te histogram

a['Rating'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Getting a plot area graph
    
a['Rating'].plot.area()
# Out:
# <Axes: >

# %%
#Using Scatter plot graph for data visualization

a['Rating'].plot.scatter(x='a', y='b')                #scatter plot doesnt work for all data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 3
#       1 #Using Scatter plot graph for data visualization
# ----> 3 a['Rating'].plot.scatter(x='a', y='b')
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\plotting\_core.py:1697, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1614 def scatter(self, x, y, s=None, c=None, **kwargs) -> PlotAccessor:
#    1615     """
#    1616     Create a scatter plot with varying marker point size and color.
#    1617
#    (...)
#    1695         ...                       colormap='viridis')
#    1696     """
# -> 1697     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\plotting\_core.py:947, in PlotAccessor.__call__(self, *args, **kwargs)
#     945         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     946     else:
# ...

# %%
#For Pie Chart graph

a['Rating'].plot.pie()
# Out:
# <Axes: ylabel='Rating'>

# %%
#To take the subplots argument

a['Rating'].plot.pie(subplots=True)
# Out:
# array([<Axes: ylabel='Rating'>], dtype=object)
